# %% [markdown]
# <a href="https://colab.research.google.com/github/guisouza565656-commits/aulas-de-prograamador-de-sistemas-senac/blob/main/C%C3%B3pia_de_Exerc%C3%ADcio1_correto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### algoritmo da soma
#
# 1  Faça um algoritmo para ler dois números e impirmir a soma dos números lidos.
#
# 1. Leia o primeiro número e guarde numa variável chamada numero01
# 2. Leia o segundo número e guarde em outra variável chamada numero02
#
# 3. faça a soma das duas variavel e guarde o resultado chamada soma
#
# 4. mostre o resultado

# %%
Numero01 = int(input('Digite o primeiro número: '))
Numero02 = int(input('Digite o segundo número: '))
Soma = Numero01 + Numero02
print(f'O resultado é: {Soma}')
# Out:
# Digite o primeiro número: 67
# Digite o segundo número: 32
# O resultado é: 99

# %% [markdown]
# ### algoritmo da média
#
# 2 faça um algoritmo para ler três números e imprimir a soma, média e produtos dos números lidos.
#
# 1. Leia o primeiro número e salve na variável num1
# 2. Leia o segundo número e salve na variável num2
# 3. Leia o terceiro número e salve na variável num3
# 4. Some os 3 números e salve na variável soma
# 5. Mostre o resultado da soma

# %%
num1 = int(input("digite o primeiro número:"))
num2 = int(input("digite o segundo número:"))
num3 = int(input("digite o terceiro número:"))
soma = num1 + num2 + num3
print(f"a soma dos números é {soma}")
# Out:
# digite o primeiro número:89
# digite o segundo número:56
# digite o terceiro número:23
# a soma dos números é 168

# %% [markdown]
# ### algoritmo do maior e menor
# 3 Faça um algoritmo para ler dois números e imprimir o maior, o menor ou então dizer se são iguais.
# 1. Leia o primeiro número e salve na variável num1
# 2. Leia o segundo número e salve na variável num2
# 3. Descobrir o maior
# 4. Mostre o menor
# 5. Descobrir o menor
# 6. Mostrar o menor
# 7. Descobrir se são iguais
# 8. Mostrar se são iguais

# %%
num1 = int(input("digite o primeiro número:"))
num2 = int(input("digite o segundo número:"))
if num1 > num2:
    print(f"o maior número é {num1}")
    print(f"o menor número é {num2}")
elif num2 > num1:
    print(f"o maior número é {num2}")
    print(f"o menor número é {num1}")
else:
    print("os números são iguais")
# Out:
# digite o primeiro número:56
# digite o segundo número:34
# o maior número é 56
# o menor número é 34

# %% [markdown]
# #exemplo 2

# %%
num1 = float(input("digite o primeiro número:"))
num2 = float(input("digite o segundo número:"))
if num1 > num2:
    print(f"o maior número é {num1}")
    print(f"o menor número é {num2}")
elif num1 < num2:
    print(f"o maior número é {num2}")
    print(f"o menor número é {num1}")
else:
    print("os números são iguais")
# Out:
# digite o primeiro número:34
# digite o segundo número:21
# o maior número é 34.0
# o menor número é 21.0

# %% [markdown]
# 4. Faça um algoritmo para ler um número inteiro e dizer se o número lido é par ou impar.
#
# Algoritimo:
#
# 1. . Leia o primeiro número e salve na variável num
# 2. descobrir se é par ou impar: dividindo por 2 e se tiver um resto o numero é impar
# 3. mostre o resultado

# %%
num = int(input("digite um número:"))
if num % 2 == 0:
    print(f"o número é par")
else:
    print(f"o número é impar")
# Out:
# digite um número:5
# o número é impar

# %% [markdown]
# 5 Faça um algoritmo para ler dois números A e B e dizer se A é divisível por B
# 1. leia o primero numero e salve num1
# 2. leia o segundo numero e salve num2
# 3. verifique se a divisão de A e B é igual a 0
# 4. se o resultado da divisao for igual a 0, solicite outro numero
#
# 5. mostre o resultado

# %%
num1 = int(input("digite um número:"))
num2 = int(input("digite um número:"))
if num1 % num2 == 0:
    print(f"o número {num1} é divisível por {num2}")
    num2 = int(input("digite um número:"))
else:
    print(f"o número {num1} não é divisível por {num2}")
# Out:
# digite um número:10
# digite um número:4
# o número 10 não é divisível por 4

# %% [markdown]
# 6 Faça um algoritmo para ler dois números e imprimi-los em ordem crescente.
#
# 1. infome o primeiro numero e salve imp1
# 2. imforme o segundo numero e salve imp2
# 3. mostrar o menor numero
# 4. mostrar o maior em seguida

# %%
imp1 = int(input("digite um número:"))
imp2 = int(input("digite um número:"))
if imp1 < imp2:
    print(f"o menor número é {imp1}")
    print(f"o maior número é {imp2}")
else:
    print(f"o menor número é {imp2}")
    print(f"o maior número é {imp1}")
# Out:
# digite um número:67
# digite um número:23
# o menor número é 23
# o maior número é 67

# %% [markdown]
# 7 Faça um algoritmo para ler três números e imprimir o maior.
# 1. iforme o primeiro numero e salve imp1
# 2. informe o segundo numero e salve imp2
# 3. informe o terceiro numero e salve imp3
# 4. separe os trés numeros e infome qual o menor
# 5. em seguida mostre qual o maior

# %%
imp1 = int(input("digite um número:"))
imp2 = int(input("digite um número:"))
imp3 = int(input("digite um número:"))
if imp1 > imp2 and imp1 > imp3:
    print(f"o maior número é {imp1}")
    if imp2 < imp3:
        print(f"o menor número é {imp2}")
    else:
        print(f"o menor número é {imp3}")
# Out:
# digite um número:67
# digite um número:45
# digite um número:23
# o maior número é 67
# o menor número é 23

# %% [markdown]
# 8 Faça um algoritmo para ler três números e imprimir se estes podem ou não formar um triângulo.
#
# Observação – Para formar os lados de um triângulo cada um dos valores tem que ser menor que a soma dos outros dois.
#
# 1. leia o primero numero salve imp1
# 2. leia o segundo numero e salve imp2
# 3. leia o terceiro numero e salve imp3
# 4. analise os tres numeros e veja se podem forma um triangulo
# 5. os numeros informados a soma de cada um dos valores tem que ser menor que a dos outros dois
# 6. imprima os tres valores
# 7. iforme se sim, é posivel fazer um triangulo
# 8. ou informe se não , não é possivel fazer um triangulo

# %%
imp1 = int(input("digite um número:"))
imp2 = int(input("digite um número:"))
imp3 = int(input("digite um número:"))
if imp1 < imp2 + imp3 and imp2 < imp1 + imp3 and imp3 < imp1 + imp2:
    print("é possivel fazer um triangulo")
else:
    print("não é possivel fazer um triangulo")
# Out:
# digite um número:67
# digite um número:78
# digite um número:56
# é possivel fazer um triangulo

# %% [markdown]
# 9 Faça um algoritmo para ler três números e se estes poderem formar um triângulo dizer se o triângulo é “EQUILÁTERO”, “ISÓSCELES” OU “ESCALENO”.
# # obeservação
# Para classificar o tipo de triângulo, precisamos verificar as seguintes condições:
#
# Equilátero: Todos os três lados são iguais.
# Isósceles: Exatamente dois lados são iguais.
# Escaleno: Nenhum dos lados é igual.
